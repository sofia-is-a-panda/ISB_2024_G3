# %%
import matplotlib.pyplot as plt
import numpy as np

#Antes de realizar el ploteo correspondiente, es necesario tener las siguientes consideraciones:

#La frecuencia de muestreo del bitalino es de 1000 Hz.
#Asimismo, la funcion de tranferencia utilizada para obtener la gráfica fue:
# (((ADC/1024)-0.5)*3.3)/41782

#-------PLOTEO DE LA SEÑAL 1
array= np.genfromtxt("/content/Reposo-EEG.txt",delimiter="	",skip_header = 2) #leemos el archivo txt

M = array[:,-2].shape[0] #longitud de la señal
valores=array[:,-2]

cantidad=np.size(valores);
#Siendo la frecuencia de muestreo del BITalino de 1000 Hz

tiempo=np.arange(0,cantidad)
tiempo=tiempo/1000

valores=(((valores/1024)-0.5)*3.3)/(41782)
valores=valores*1000000
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('EEG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 1 - Sin movimientos oculares y ojos cerrados - EEG')
#plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('EEG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 1 - Acotado en 5 a 8 s')
plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('EEG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 1 - Acotado en 15 a 18 s')
plt.xlim([15,18])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('EEG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 1 - Acotado en 25 a 28 s')
plt.xlim([25,28])
plt.grid(True)

# %%
#-------PLOTEO DE LA SEÑAL 2
array = np.genfromtxt("/content/2 EEG.txt",delimiter="	",skip_header = 2) #leemos el archivo txt

M = array[:,-2].shape[0] #longitud de la señal
valores=array[:,-2]

cantidad=np.size(valores);
#Siendo la frecuencia de muestreo del BITalino de 1000 Hz

tiempo=np.arange(0,cantidad)
tiempo=tiempo/1000

valores=(((valores/1024)-0.5)*3.3)/(41782)
valores=valores*1000000
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Ciclo de Ojos Abiertos y Ojos Cerrados - EEG')
#plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Ciclo de Ojos Abiertos y Ojos Cerrados - Acotado en 5 a 8 s')
plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Ciclo de Ojos Abiertos y Ojos Cerrados - Acotado en 15 a 18 s')
plt.xlim([15,18])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Ciclo de Ojos Abiertos y Ojos Cerrados - Acotado en 25 a 28 s')
plt.xlim([25,28])
plt.grid(True)

# %%
#-------PLOTEO DE LA SEÑAL 3
array = np.genfromtxt("/content/3 EEG.txt",delimiter="	",skip_header = 2) #leemos el archivo txt

M = array[:,-2].shape[0] #longitud de la señal
valores=array[:,-2]

cantidad=np.size(valores);
#Siendo la frecuencia de muestreo del BITalino de 1000 Hz

tiempo=np.arange(0,cantidad)
tiempo=tiempo/1000

valores=(((valores/1024)-0.5)*3.3)/(41782)
valores=valores*1000000
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 2 - Sin movimientos oculares y ojos cerrados - EEG')
#plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 2 - Acotado en 5 a 8 s')
plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 2 - Acotado en 15 a 18 s')
plt.xlim([15,18])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Base 2 - Acotado en 25 a 28 s')
plt.xlim([25,28])
plt.grid(True)

# %%
#-------PLOTEO DE LA SEÑAL 4
array = np.genfromtxt("/content/4 - EEG.txt",delimiter="	",skip_header = 2) #leemos el archivo txt

M = array[:,-2].shape[0] #longitud de la señal
valores=array[:,-2]

cantidad=np.size(valores);
#Siendo la frecuencia de muestreo del BITalino de 1000 Hz

tiempo=np.arange(0,cantidad)
tiempo=tiempo/1000

valores=(((valores/1024)-0.5)*3.3)/(41782)
valores=valores*1000000
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Preguntas - EEG')
#plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Preguntas - Acotado en 5 a 8 s')
plt.xlim([5,8])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Preguntas - Acotado en 15 a 18 s')
plt.xlim([15,18])
plt.grid(True)

# %%
plt.figure(figsize=[12,4])
plt.plot(tiempo, valores)
plt.ylabel('ECG Signal (uV)')
plt.xlabel('Time (s)');
plt.title('Preguntas - Acotado en 25 a 28 s')
plt.xlim([25,28])
plt.grid(True)
